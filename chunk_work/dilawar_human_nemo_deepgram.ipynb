# %%
import pandas as pd

# %%
df = pd.read_excel('Abdullah_human_nemo_deepgram_(Duplicates).xlsx')

# %%
df
# Out:
#         sno                                       recoding_url      user  \
# 0        66  http://192.168.88.254/transcription_wav/transc...  abdullah
# 1        69  http://192.168.88.254/transcription_wav/transc...  abdullah
# 2        71  http://192.168.88.254/transcription_wav/transc...  abdullah
# 3        75  http://192.168.88.254/transcription_wav/transc...  abdullah
# 4        97  http://192.168.88.254/transcription_wav/transc...  abdullah
# ...     ...                                                ...       ...
# 1492  13936  http://192.168.88.254/transcription_wav/transc...  abdullah
# 1493  13943  http://192.168.88.254/transcription_wav/transc...  abdullah
# 1494  13949  http://192.168.88.254/transcription_wav/transc...  abdullah
# 1495  13950  http://192.168.88.254/transcription_wav/transc...  abdullah
# 1496  13953  http://192.168.88.254/transcription_wav/transc...  abdullah
#
#                                        human_transcribe  \
# ...

# %%
df.shape
# Out:
# (1497, 8)

# %%
len(df['human_transcribe'].value_counts())
# Out:
# 1331

# %%
1497-1331
# Out:
# 166

# %%
# Removing Duplicates
print(len(df))
df_rm_dup = df.drop_duplicates(subset='human_transcribe')
print(len(df_rm_dup))
# Out:
# 1497
# 1331

# %%
# bot_transcription = []
# count = 1

# for i in  new_df_rmd_dup['data.rawTranscriptions']:
#     if 'press' in i:
#         print('\n ' + str(count) + ' ' + i)
#         bot_transcription.append(i)
#         count+=1

# %%
# df = df[df.line_race != 0]
new_df_rmd_dup_trans = new_df_rmd_dup

for i in bot_transcription:
    new_df_rmd_dup_trans = new_df_rmd_dup_trans[new_df_rmd_dup_trans['data.rawTranscriptions'] != i]

# %%
# bot_transcription = []
count = 1

for i in  df_rm_dup['human_transcribe']:
    if 'what' in i:
        print('\n ' + str(count) + ' ' + i)
#         bot_transcription.append(i)
        count+=1
# Out:
#  1 a what
#
#  2 about the debt program whats that
#
#  3 about what
#
#  4 about what sir
#
#  5 actually what guy says my account was being suspended i needed to update my information
#
#  6 just what you need
#
#  7 no i dont now what you need so no
#
#  8 sir I ve no debt i dont know what you want but i listen
#
#  9 what are you speaking about
#
#  10 what do you selling honey
#
#  11 what is the status of my profile
#
#  12 what the fuck do you want
#
#  13 whats terrible
#
#  14 all right okay and will i apologize for i have having that question so go head ashley what else is is helpful
#
#  15 all right well let me all you i dont use credit card so what the hell do you want
#
#  16 america what
#
#  17 american debt what have i got to do with americas debt
#
#  18 and what your name
#
#  19 and did you know what i just said
#
# ...

# %%
# Abdullah_human_nemo_deepgram_(Cleaned)

df_rm_dup.to_excel('Abdullah_human_nemo_deepgram_(Cleaned).xlsx', index=False)
