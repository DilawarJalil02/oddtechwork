# %%
import os

employees = os.listdir('train_dir/')

# %%
employee_data = {
                'oddTech_1':'Muhammad Ahmed Ansari',
                'oddTech_2':'Danish Inam',
                'oddTech_3':'Muhammad Osama Rizwan',
                'oddTech_4':'Azim Khan',
                'oddTech_5':'Raheel',
                'oddTech_6':'Hasnain Ali',
                'oddTech_7':'Zahida Naz',
                'oddTech_8':'Arish Khan',
                'oddTech_9':'Abdullah Bin Abdul Qadeer',
                'oddTech_10':'Abdul Saboor',
                'oddTech_11':'Dilawar Jalil',
                'oddTech_12':'Sohaib Asif',
                'oddTech_13':'Muhammad Aqib',
                'oddTech_14':'Muhammad Owais',
                'oddTech_15':'Muhammad Usama',
                'oddTech_16':'Muhammad Furqan Khursheed',
                'oddTech_17':'Farhan Asif',
                'oddTech_18':'Ismail Ishaq',
                'oddTech_19':'Furqan',
                'oddTech_20':'Muhammad Zeeshan'
                }

for i in employees:
    emp_name = i.split('.')
    print(employee_data[emp_name[0]], '--', emp_name[0])
# Out:
# Muhammad Ahmed Ansari -- oddTech_1
# Abdul Saboor -- oddTech_10
# Dilawar Jalil -- oddTech_11
# Sohaib Asif -- oddTech_12
# Muhammad Aqib -- oddTech_13
# Muhammad Owais -- oddTech_14
# Muhammad Usama -- oddTech_15
# Muhammad Furqan Khursheed -- oddTech_16
# Farhan Asif -- oddTech_17
# Ismail Ishaq -- oddTech_18
# Furqan -- oddTech_19
# Danish Inam -- oddTech_2
# Muhammad Zeeshan -- oddTech_20
# Muhammad Osama Rizwan -- oddTech_3
# Azim Khan -- oddTech_4
# Raheel -- oddTech_5
# Hasnain Ali -- oddTech_6
# Zahida Naz -- oddTech_7
# Arish Khan -- oddTech_8
# Abdullah Bin Abdul Qadeer -- oddTech_9

# %%
import face_recognition
from PIL import Image, ImageDraw
import numpy as np

# This is an example of running face recognition on a single image
# and drawing a box around each person that was identified.

# Load a sample picture and learn how to recognize it.
obama_image = face_recognition.load_image_file("obama.jpg")
obama_face_encoding = face_recognition.face_encodings(obama_image, num_jitters=5)[0]
# obama_face_encoding = face_recognition.face_encodings(obama_image)[0]

# Load a second sample picture and learn how to recognize it.
biden_image = face_recognition.load_image_file("biden.jpg")
biden_face_encoding = face_recognition.face_encodings(biden_image, num_jitters=5)[0]
# biden_face_encoding = face_recognition.face_encodings(biden_image)[0]

# Load a second sample picture and learn how to recognize it.
dilawar_image = face_recognition.load_image_file("dilawar.jpg")
dilawar_face_encoding = face_recognition.face_encodings(dilawar_image, num_jitters=5)[0]
# dilawar_face_encoding = face_recognition.face_encodings(dilawar_image)[0]

# Load a second sample picture and learn how to recognize it.
furqan_image = face_recognition.load_image_file("furqan.jpg")
furqan_face_encoding = face_recognition.face_encodings(furqan_image, num_jitters=5)[0]
# furqan_face_encoding = face_recognition.face_encodings(furqan_image)[0]


# Load a second sample picture and learn how to recognize it.
ab_image = face_recognition.load_image_file("abdullah.jpg")
ab_face_encoding = face_recognition.face_encodings(ab_image, num_jitters=5)[0]
# ab_face_encoding = face_recognition.face_encodings(ab_image)[0]


# Load a second sample picture and learn how to recognize it.
aqib_image = face_recognition.load_image_file("aqib.jpg")
aqib_face_encoding = face_recognition.face_encodings(aqib_image, num_jitters=5)[0]
# aqib_face_encoding = face_recognition.face_encodings(aqib_image)[0]


# Load a second sample picture and learn how to recognize it.
osama_image = face_recognition.load_image_file("osama.jpg")
osama_face_encoding = face_recognition.face_encodings(osama_image, num_jitters=5)[0]
# osama_face_encoding = face_recognition.face_encodings(osama_image)[0]

# # Load a second sample picture and learn how to recognize it.
# A_saboor_image = face_recognition.load_image_file("saboor.jpeg")
# A_saboor_face_encoding = face_recognition.face_encodings(A_saboor_image, num_jitters=50)[0]

# # Load a second sample picture and learn how to recognize it.
# owais_image = face_recognition.load_image_file("owais.jpeg")
# owais_face_encoding = face_recognition.face_encodings(owais_image, num_jitters=50)[0]

# Load a second sample picture and learn how to recognize it.
junaid_image = face_recognition.load_image_file("junaid.jpg")
junaid_face_encoding = face_recognition.face_encodings(junaid_image, num_jitters=5)[0]
# junaid_face_encoding = face_recognition.face_encodings(junaid_image)[0]

# Load a second sample picture and learn how to recognize it.
sohaib_image = face_recognition.load_image_file("sohaib.jpg")
sohaib_face_encoding = face_recognition.face_encodings(sohaib_image, num_jitters=5)[0]
# sohaib_face_encoding = face_recognition.face_encodings(sohaib_image)[0]


# # Create arrays of known face encodings and their names
# known_face_encodings = [
#     obama_face_encoding,
#     biden_face_encoding
# ]
# known_face_names = [
#     "Barack Obama",
#     "Joe Biden"
# ]


# Create arrays of known face encodings and their names
known_face_encodings = [
    obama_face_encoding,
    biden_face_encoding,
    dilawar_face_encoding,
    furqan_face_encoding,
    ab_face_encoding,
    aqib_face_encoding,
    osama_face_encoding,
#     A_saboor_face_encoding,
#     owais_face_encoding,
    junaid_face_encoding,
    sohaib_face_encoding
    
]
known_face_names = [
    "Barack Obama",
    "Joe Biden",
    "Dilawar Jalil",
    "Muhammad Furqan Khursheed",
    "Abdullah Bin Abdul Qadeer",
    "Muhammad Aqib",
    "Muhammad Usama",
#     "Abdul Saboor",
#     "Muhammad Owais",
    "Junaid",
    "Sohaib Asif"
]

# %%
# Load an image with an unknown face
unknown_image = face_recognition.load_image_file("train_dir/oddTech_13.jpg")

# Find all the faces and face encodings in the unknown image
face_locations = face_recognition.face_locations(unknown_image, number_of_times_to_upsample=2)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations, num_jitters=5)
# face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

# Convert the image to a PIL-format image so that we can draw on top of it with the Pillow library
# See http://pillow.readthedocs.io/ for more about PIL/Pillow
# pil_image = Image.fromarray(unknown_image)
# Create a Pillow ImageDraw Draw instance to draw with
# draw = ImageDraw.Draw(pil_image)

# Loop through each face found in the unknown image
for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    # See if the face is a match for the known face(s)
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding, tolerance=0.48)

    name = "Unknown"

    # Or instead, use the known face with the smallest distance to the new face
    face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
    best_match_index = np.argmin(face_distances)
    if matches[best_match_index]:
        name = known_face_names[best_match_index]
    print('name', name)
    print('face_distances', face_distances)
    print('best_match_index', best_match_index)
    print('matches[best_match_index]', matches[best_match_index])
    print('known_face_names[best_match_index]', known_face_names[best_match_index])
    print('known_face_names', known_face_names)
# Out:
# name Muhammad Aqib
# face_distances [0.75777415 0.93959521 0.58771123 0.56481523 0.56128746 0.26570299
#  0.58988436 0.65595467 0.48504404]
# best_match_index 5
# matches[best_match_index] True
# known_face_names[best_match_index] Muhammad Aqib
# known_face_names ['Barack Obama', 'Joe Biden', 'Dilawar Jalil', 'Muhammad Furqan Khursheed', 'Abdullah Bin Abdul Qadeer', 'Muhammad Aqib', 'Muhammad Usama', 'Junaid', 'Sohaib Asif']

# %%
for i in range(len(known_face_encodings)):
    print(i+1, known_face_encodings[i])
# Out:
# 1 [-0.10818639  0.13052745  0.00771881 -0.07543054  0.01743141  0.00179178
#  -0.08354553 -0.09396275  0.18063597 -0.09719114  0.25610027  0.08773231
#  -0.20935546 -0.13759834  0.032559    0.12223016 -0.18671671 -0.08269657
#  -0.11176056 -0.11978146  0.02395985 -0.00707984  0.09394769  0.04715727
#  -0.13355325 -0.34060478 -0.05594249 -0.19016056 -0.00686722 -0.0946048
#  -0.0690143  -0.01010905 -0.18037684 -0.10434724  0.02510886 -0.02102686
#   0.00449377  0.01253378  0.20251651  0.02929226 -0.109953    0.08451191
#   0.02446087  0.23453347  0.27584174  0.08695272 -0.00276193 -0.0930987
#   0.11461157 -0.23233528  0.07821044  0.15159957  0.05936128  0.03559398
#   0.09257654 -0.18203489  0.00805048  0.09172658 -0.14639053  0.0194656
#   0.01567446 -0.06879818 -0.06537265  0.03712117  0.20793565  0.11615454
#  -0.1334451  -0.04913404  0.15011202 -0.02688009  0.02147816  0.01423515
#  -0.18543975 -0.20640926 -0.22693615  0.09326917  0.37971053  0.18906593
# ...
